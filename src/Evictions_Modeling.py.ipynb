# %%
from ml_utils import Pipeline
import pandas as pd
import numpy as np
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
pipeline = Pipeline()
df = pipeline.load_chunk()

df.tail()
# Out:
# Connected to evictions DB.
# Set schema to 'evictions'.
# Set background cursor.
# (2270338, 'NV', '320310035043', 2001, '35.04.3', 'Washoe County, Nevada', 79.34, 1.68, 3.06, 41.76, 2170.74, 5321.61, 1.0, 92.13, 0.55, 4.67, 1.14, 0.59, 0.0, 0.93, 0.0, 6.0, 1.0, 1.0, 16.36, 16.36, False, False, '32', '32031', '32031003504', '320310035043', 2001, 0, 1)
#          _id state_code        geo_id  year     name          parent_location  \
# 995  2387223         NY  360810058004  2004     58.4  Queens County, New York
# 996  2387253         NY  360810059003  2004     59.3  Queens County, New York
# 997  2387330         NY  360810062022  2001  62.02.2  Queens County, New York
# 998  2387485         NY  360810065023  2006  65.02.3  Queens County, New York
# 999  2387491         NY  360810069001  2002     69.1  Queens County, New York
#
#      population  poverty_rate  pct_renter_occupied  median_gross_rent  \
# 995       957.0          5.22                23.89             909.00
# 996      1192.0         14.18                89.26             748.00
# 997       674.0          7.69                40.28             116.32
# 998      1887.0          0.00                81.45            1207.00
# 999      1367.0         25.60                80.50             796.00
#
#             ...           eviction_filing_rate  imputed  subbed  state  \
# 995         ...                           1.39    False   False     36
# 996         ...                           8.67    False   False     36
# 997         ...                           3.76    False   False     36
# 998         ...                           4.76    False   False     36
# 999         ...                           8.33    False   False     36
#
#      county        tract  geo_id (repeated)  year (repeated)  top20_evictions  \
# 995   36081  36081005800       360810058004             2004                0
# 996   36081  36081005900       360810059003             2004                1
# 997   36081  36081006202       360810062022             2001                0
# 998   36081  36081006502       360810065023             2006                1
# 999   36081  36081006900       360810069001             2002                0
#
#      top20_eviction_rate
# 995                    0
# 996                    0
# 997                    0
# 998                    0
# 999                    0
#
# [5 rows x 35 columns]

# %%
# define models to run
models_to_run=['RF','LR', 'NB', 'GB', 'DT', 'KNN'] #'SVM'
# select features to use
features  =  ['geo_id', 'population', 'evictions', 'eviction_filings', 'eviction_filing_rate', 'renter_occupied_households']

classifiers, params = pipeline.get_classifiers()
df = pipeline.fill_missing(df)

X = df[features]
y = df['top20_eviction_rate']

results_df = pipeline.classify(models_to_run, classifiers, params, X,y)


# save to csv
#results_df.to_csv('results.csv', index=False)
results_df
# Out:
# Running through model RF...
# Running through model LR...
# Running through model NB...
# Running through model GB...
# Running through model DT...
# Running through model KNN...
#   model_type                                                clf  \
# 0         RF  (DecisionTreeClassifier(class_weight=None, cri...
# 1         LR  LogisticRegression(C=0.01, class_weight=None, ...
# 2         NB                            GaussianNB(priors=None)
# 3         GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 4         DT  DecisionTreeClassifier(class_weight=None, crit...
# 5        KNN  KNeighborsClassifier(algorithm='auto', leaf_si...
#
#                                           parameters   auc-roc    p_at_5  \
# 0  {'max_depth': 1, 'max_features': 'sqrt', 'min_...  0.959097  1.000000
# 1                       {'C': 0.01, 'penalty': 'l1'}  0.996149  1.000000
# 2                                                 {}  0.512779  0.000000
# 3  {'learning_rate': 0.1, 'max_depth': 1, 'n_esti...  0.954312  0.916667
# 4  {'criterion': 'gini', 'max_depth': 1, 'min_sam...  0.914868  1.000000
# 5  {'algorithm': 'auto', 'n_neighbors': 5, 'weigh...  0.667873  0.416667
#
#    p_at_10  p_at_20
# 0     0.56     0.76
# 1     1.00     0.82
# 2     0.20     0.24
# 3     0.52     0.72
# 4     0.80     0.70
# 5     0.28     0.32
