# %%
from ml_utils import Pipeline
import pandas as pd
import numpy as np
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
pipeline = Pipeline()
df = pipeline.load_chunk()
for i in range(1,9):
    df = df.append(pipeline.load_chunk())
    print("Loaded chunk {}".format(i+1))

df.tail()
# Out:
# Connected to evictions DB.
# Set schema to 'evictions'.
# Set background cursor.
# Loaded chunk 2
# Loaded chunk 3
# Loaded chunk 4
# Loaded chunk 5
# Loaded chunk 6
# Loaded chunk 7
# Loaded chunk 8
# Loaded chunk 9
#         _id state_code        geo_id  year      name  \
# 995  816488         FL  120150201031  2013  201.03.1
# 996  816663         FL  120150304012  2014  304.01.2
# 997  816684         FL  120150103022  2015  103.02.2
# 998  816693         FL  120150104043  2015  104.04.3
# 999  816715         FL  120150202024  2015  202.02.4
#
#                parent_location  population  poverty_rate  pct_renter_occupied  \
# 995  Charlotte County, Florida      1370.0          5.35                 0.00
# 996  Charlotte County, Florida       583.0         22.48                38.31
# 997  Charlotte County, Florida      1522.0         18.63                75.70
# 998  Charlotte County, Florida      1337.0          0.00                 2.36
# 999  Charlotte County, Florida      1390.0          5.09                 8.96
#
#      median_gross_rent         ...           eviction_filing_rate  imputed  \
# 995                NaN         ...                           1.72    False
# 996              574.0         ...                           2.09    False
# 997              622.0         ...                           5.67    False
# 998                NaN         ...                           1.32    False
# 999                NaN         ...                           7.87    False
#
#      subbed  state  county        tract  geo_id (repeated)  year (repeated)  \
# 995   False     12   12015  12015020103       120150201031             2013
# 996   False     12   12015  12015030401       120150304012             2014
# 997   False     12   12015  12015010302       120150103022             2015
# 998   False     12   12015  12015010404       120150104043             2015
# 999   False     12   12015  12015020202       120150202024             2015
#
#      top20_evictions  top20_eviction_rate
# 995                0                    0
# 996                0                    0
# 997                1                    0
# 998                0                    0
# 999                0                    0
#
# [5 rows x 35 columns]

# %%
# define models to run
models_to_run=['RF','LR', 'NB', 'GB', 'DT', 'KNN'] #'SVM'

# select features to use
features  =  ['geo_id', 'population', 'evictions', 'eviction_filings', 'eviction_filing_rate', 'renter_occupied_households']

classifiers, params = pipeline.get_classifiers()
df = pipeline.fill_missing(df)

X = df[features]
y = df['top20_eviction_rate']

results_df = pipeline.classify(models_to_run, classifiers, params, X,y)


# save to csv
#results_df.to_csv('results.csv', index=False)
results_df.sort_values(by=['auc-roc'], ascending=False)
# Out:
# Running through model RF...
# Running through model LR...
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\base.py:340: RuntimeWarning: overflow encountered in exp
#   np.exp(prob, prob)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\base.py:340: RuntimeWarning: overflow encountered in exp
#   np.exp(prob, prob)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\base.py:340: RuntimeWarning: overflow encountered in exp
#   np.exp(prob, prob)
# Running through model NB...
# Running through model GB...
# Running through model DT...
# Running through model KNN...
#     model_type                                                clf  \
# 29          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 41          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 28          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 34          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 22          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 38          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 40          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 9           LR  LogisticRegression(C=10, class_weight=None, du...
# 7           LR  LogisticRegression(C=10, class_weight=None, du...
# 5           LR  LogisticRegression(C=10, class_weight=None, du...
# 21          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 25          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 26          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 35          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 16          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 18          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 37          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 15          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 27          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 19          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 13          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 3           LR  LogisticRegression(C=10, class_weight=None, du...
# 12          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 47          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 30          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 17          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 56          DT  DecisionTreeClassifier(class_weight=None, crit...
# 31          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 24          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 46          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# ..         ...                                                ...
# 89         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 92         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 116        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 104        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 88         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 112        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 100        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 94         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 106        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 118        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 111        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 99         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 87         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 86         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 98         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 110        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 108        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 109        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 85         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 97         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 96         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 84         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 11          NB                            GaussianNB(priors=None)
# 0           RF  (DecisionTreeClassifier(class_weight=None, cri...
# 1           LR  LogisticRegression(C=10, class_weight=None, du...
# 8           LR  LogisticRegression(C=10, class_weight=None, du...
# 6           LR  LogisticRegression(C=10, class_weight=None, du...
# 10          LR  LogisticRegression(C=10, class_weight=None, du...
# 2           LR  LogisticRegression(C=10, class_weight=None, du...
# 4           LR  LogisticRegression(C=10, class_weight=None, du...
#
#                                             parameters   auc-roc    p_at_5  \
# 29   {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...  0.998016  1.000000
# 41   {'learning_rate': 0.5, 'max_depth': 5, 'n_esti...  0.997722  1.000000
# 28   {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...  0.997567  1.000000
# 34   {'learning_rate': 0.1, 'max_depth': 50, 'n_est...  0.997522  1.000000
# 22   {'learning_rate': 0.001, 'max_depth': 50, 'n_e...  0.996963  1.000000
# 38   {'learning_rate': 0.5, 'max_depth': 5, 'n_esti...  0.996166  1.000000
# 40   {'learning_rate': 0.5, 'max_depth': 5, 'n_esti...  0.996029  0.991071
# 9                           {'C': 10, 'penalty': 'l1'}  0.995430  1.000000
# 7                            {'C': 1, 'penalty': 'l1'}  0.995376  1.000000
# 5                          {'C': 0.1, 'penalty': 'l1'}  0.995126  1.000000
# 21   {'learning_rate': 0.001, 'max_depth': 50, 'n_e...  0.994623  1.000000
# 25   {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...  0.994184  1.000000
# 26   {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...  0.994175  1.000000
# 35   {'learning_rate': 0.1, 'max_depth': 50, 'n_est...  0.993273  0.964286
# 16   {'learning_rate': 0.001, 'max_depth': 5, 'n_es...  0.993097  1.000000
# 18   {'learning_rate': 0.001, 'max_depth': 50, 'n_e...  0.992122  0.991071
# 37   {'learning_rate': 0.5, 'max_depth': 5, 'n_esti...  0.992104  0.982143
# 15   {'learning_rate': 0.001, 'max_depth': 5, 'n_es...  0.991124  1.000000
# 27   {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...  0.990491  0.964286
# 19   {'learning_rate': 0.001, 'max_depth': 50, 'n_e...  0.990363  1.000000
# 13   {'learning_rate': 0.001, 'max_depth': 5, 'n_es...  0.990065  0.991071
# 3                        {'C': 0.001, 'penalty': 'l1'}  0.989540  1.000000
# 12   {'learning_rate': 0.001, 'max_depth': 5, 'n_es...  0.989311  0.973214
# 47   {'learning_rate': 0.5, 'max_depth': 50, 'n_est...  0.988277  0.982143
# 30   {'learning_rate': 0.1, 'max_depth': 50, 'n_est...  0.988040  1.000000
# 17   {'learning_rate': 0.001, 'max_depth': 5, 'n_es...  0.986963  0.928571
# 56   {'criterion': 'gini', 'max_depth': 10, 'min_sa...  0.986417  0.857143
# 31   {'learning_rate': 0.1, 'max_depth': 50, 'n_est...  0.984796  1.000000
# 24   {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...  0.984389  0.955357
# 46   {'learning_rate': 0.5, 'max_depth': 50, 'n_est...  0.983761  0.919643
# ..                                                 ...       ...       ...
# 89   {'algorithm': 'auto', 'n_neighbors': 10, 'weig...  0.740527  0.401786
# 92   {'algorithm': 'auto', 'n_neighbors': 50, 'weig...  0.735500  0.437500
# 116  {'algorithm': 'kd_tree', 'n_neighbors': 50, 'w...  0.735500  0.437500
# 104  {'algorithm': 'ball_tree', 'n_neighbors': 50, ...  0.735500  0.437500
# 88   {'algorithm': 'auto', 'n_neighbors': 10, 'weig...  0.732503  0.446429
# 112  {'algorithm': 'kd_tree', 'n_neighbors': 10, 'w...  0.732503  0.446429
# 100  {'algorithm': 'ball_tree', 'n_neighbors': 10, ...  0.732503  0.446429
# 94   {'algorithm': 'auto', 'n_neighbors': 100, 'wei...  0.714876  0.428571
# 106  {'algorithm': 'ball_tree', 'n_neighbors': 100,...  0.714876  0.428571
# 118  {'algorithm': 'kd_tree', 'n_neighbors': 100, '...  0.714876  0.428571
# 111  {'algorithm': 'kd_tree', 'n_neighbors': 5, 'we...  0.712151  0.383929
# 99   {'algorithm': 'ball_tree', 'n_neighbors': 5, '...  0.712151  0.383929
# 87   {'algorithm': 'auto', 'n_neighbors': 5, 'weigh...  0.712151  0.383929
# 86   {'algorithm': 'auto', 'n_neighbors': 5, 'weigh...  0.708205  0.285714
# 98   {'algorithm': 'ball_tree', 'n_neighbors': 5, '...  0.708205  0.285714
# 110  {'algorithm': 'kd_tree', 'n_neighbors': 5, 'we...  0.708205  0.285714
# 108  {'algorithm': 'kd_tree', 'n_neighbors': 1, 'we...  0.592228  0.008929
# 109  {'algorithm': 'kd_tree', 'n_neighbors': 1, 'we...  0.592228  0.008929
# 85   {'algorithm': 'auto', 'n_neighbors': 1, 'weigh...  0.592228  0.008929
# 97   {'algorithm': 'ball_tree', 'n_neighbors': 1, '...  0.592228  0.008929
# 96   {'algorithm': 'ball_tree', 'n_neighbors': 1, '...  0.592228  0.008929
# 84   {'algorithm': 'auto', 'n_neighbors': 1, 'weigh...  0.592228  0.008929
# 11                                                  {}  0.551399  0.178571
# 0    {'max_depth': 1, 'max_features': 'sqrt', 'min_...  0.483457  0.000000
# 1                        {'C': 1e-05, 'penalty': 'l1'}  0.457048  0.098214
# 8                            {'C': 1, 'penalty': 'l2'}  0.448601  0.062500
# 6                          {'C': 0.1, 'penalty': 'l2'}  0.448600  0.062500
# 10                          {'C': 10, 'penalty': 'l2'}  0.448600  0.062500
# 2                        {'C': 1e-05, 'penalty': 'l2'}  0.448600  0.062500
# 4                        {'C': 0.001, 'penalty': 'l2'}  0.448600  0.062500
#
#       p_at_10   p_at_20
# 29   0.995556  0.720000
# 41   0.991111  0.722222
# 28   0.991111  0.717778
# 34   1.000000  0.715556
# 22   1.000000  0.717778
# 38   0.995556  0.717778
# 40   0.986667  0.713333
# 9    0.991111  0.711111
# 7    0.991111  0.711111
# 5    0.991111  0.711111
# 21   0.991111  0.704444
# 25   0.986667  0.711111
# 26   0.968889  0.706667
# 35   0.977778  0.708889
# 16   0.968889  0.711111
# 18   0.951111  0.702222
# 37   0.964444  0.717778
# 15   0.964444  0.704444
# 27   0.977778  0.708889
# 19   0.991111  0.715556
# 13   0.937778  0.693333
# 3    0.991111  0.691111
# 12   0.933333  0.702222
# 47   0.964444  0.711111
# 30   0.977778  0.708889
# 17   0.884444  0.693333
# 56   0.928889  0.713333
# 31   0.991111  0.711111
# 24   0.928889  0.700000
# 46   0.942222  0.702222
# ..        ...       ...
# 89   0.360000  0.328889
# 92   0.355556  0.308889
# 116  0.355556  0.308889
# 104  0.355556  0.308889
# 88   0.377778  0.295556
# 112  0.377778  0.295556
# 100  0.377778  0.295556
# 94   0.346667  0.284444
# 106  0.346667  0.284444
# 118  0.346667  0.284444
# 111  0.342222  0.311111
# 99   0.342222  0.311111
# 87   0.342222  0.311111
# 86   0.364444  0.317778
# 98   0.364444  0.317778
# 110  0.364444  0.317778
# 108  0.200000  0.228889
# 109  0.200000  0.228889
# 85   0.200000  0.228889
# 97   0.200000  0.228889
# 96   0.200000  0.228889
# 84   0.200000  0.228889
# 11   0.155556  0.175556
# 0    0.000000  0.000000
# 1    0.106667  0.133333
# 8    0.080000  0.146667
# 6    0.080000  0.146667
# 10   0.080000  0.146667
# 2    0.080000  0.146667
# 4    0.080000  0.146667
#
# [120 rows x 7 columns]
