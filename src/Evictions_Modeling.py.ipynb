# %%
from ml_utils import Pipeline
import pandas as pd
import numpy as np
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
pipeline = Pipeline()
df = pipeline.load_chunk()

df.tail()
# Out:
# Connected to evictions DB.
# Set schema to 'evictions'.
# Set background cursor.
#          _id state_code        geo_id  year    name      parent_location  \
# 995  3269474         TX  485039502003  2008  9502.3  Young County, Texas
# 996  3269475         TX  485039502003  2009  9502.3  Young County, Texas
# 997  3269476         TX  485039502004  2000  9502.4  Young County, Texas
# 998  3269477         TX  485039502004  2001  9502.4  Young County, Texas
# 999  3269478         TX  485039502004  2002  9502.4  Young County, Texas
#
#      population  poverty_rate  pct_renter_occupied  median_gross_rent  \
# 995     1416.00          2.33                46.85             677.00
# 996     1416.00          2.33                46.85             677.00
# 997     1233.67         23.51                34.75             229.22
# 998     1233.67         23.51                34.75             229.22
# 999     1233.67         23.51                34.75             229.22
#
#         ...       renter_occupied_households  eviction_filings  evictions  \
# 995     ...                            231.0               0.0        0.0
# 996     ...                            231.0               0.0        0.0
# 997     ...                            178.0               0.0        0.0
# 998     ...                            178.0               0.0        0.0
# 999     ...                            178.0               1.0        1.0
#
#      eviction_rate  eviction_filing_rate  imputed  subbed  state  county  \
# 995           0.00                  0.00    False   False     48   48503
# 996           0.00                  0.00    False   False     48   48503
# 997           0.00                  0.00    False   False     48   48503
# 998           0.00                  0.00    False   False     48   48503
# 999           0.56                  0.56    False   False     48   48503
#
#            tract
# 995  48503950200
# 996  48503950200
# 997  48503950200
# 998  48503950200
# 999  48503950200
#
# [5 rows x 31 columns]

# %%
df = pipeline.load_chunk()
df.tail()
# Out:
#          _id state_code        geo_id  year name         parent_location  \
# 995  3270478         TX  480050005004  2016  5.4  Angelina County, Texas
# 996  3270479         TX  480050006001  2016  6.1  Angelina County, Texas
# 997  3270480         TX  480050006002  2016  6.2  Angelina County, Texas
# 998  3270481         TX  480050006003  2016  6.3  Angelina County, Texas
# 999  3270482         TX  480050006004  2016  6.4  Angelina County, Texas
#
#      population  poverty_rate  pct_renter_occupied  median_gross_rent  \
# 995       479.0         39.09                54.37              448.0
# 996      1558.0         12.47                21.93              975.0
# 997      1806.0         17.65                30.22              799.0
# 998      1940.0         21.76                47.90              806.0
# 999      1706.0         28.99                42.20              742.0
#
#         ...       renter_occupied_households  eviction_filings  evictions  \
# 995     ...                            143.0               NaN        NaN
# 996     ...                            150.0               NaN        NaN
# 997     ...                            182.0               NaN        NaN
# 998     ...                            200.0               NaN        NaN
# 999     ...                            195.0               NaN        NaN
#
#      eviction_rate  eviction_filing_rate  imputed  subbed  state  county  \
# 995            NaN                   NaN    False   False     48   48005
# 996            NaN                   NaN    False   False     48   48005
# 997            NaN                   NaN    False   False     48   48005
# 998            NaN                   NaN    False   False     48   48005
# 999            NaN                   NaN    False   False     48   48005
#
#            tract
# 995  48005000500
# 996  48005000600
# 997  48005000600
# 998  48005000600
# 999  48005000600
#
# [5 rows x 31 columns]

# %%
# define models to run
models_to_run=['RF','LR', 'NB', 'SVM', 'GB', 'DT', 'KNN']
# select features to use
features  =  ['geo_id', 'population', 'evictions', 'eviction_filings', 'eviction_filing_rate', 'renter_occupied_households']

classifiers, params = pipeline.get_classifiers()
df = pipeline.fill_missing(df)

X = df[features]
y = df['eviction_rate']

results_df = pipeline.classify(models_to_run, classifiers, params, X,y)


# save to csv
#results_df.to_csv('results.csv', index=False)
results_df
# Out:
# Running through model RF...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-3ac7e301e8ae> in <module>()
#      14
#      15 # call clf_loop and store results in results_df
# ---> 16 results_df = pipeline.classify(models_to_run, classifiers, params, X,y)
#      17
#      18
#
# ~\workspaces\evictions-learn\src\ml_utils.py in classify(self, models_to_run, classifiers, params, X, y)
#     219                                         try:
#     220                                                 classifier.set_params(**p)
# --> 221                                                 y_pred_probs = classifier.fit(X_train, y_train).predict_proba(X_test)[:,1]
#     222                                                 # you can also store the model, feature importances, and prediction scores
#     223                                                 # we're only storing the metrics for now
#
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     249         if sample_weight is not None:
#
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
#     452         if force_all_finite:
# --> 453             _assert_all_finite(array)
#     454
#     455     shape_repr = _shape_repr(array.shape)
#
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X)
#      42             and not np.isfinite(X).all()):
#      43         raise ValueError("Input contains NaN, infinity"
# ---> 44                          " or a value too large for %r." % X.dtype)
#      45
#      46
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
