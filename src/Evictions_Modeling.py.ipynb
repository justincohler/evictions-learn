# %%
from ml_utils import Pipeline
import pandas as pd
import numpy as np
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
pipeline = Pipeline()
df = pipeline.load_chunk()

df.tail()
# Out:
# Connected to evictions DB.
# Set schema to 'evictions'.
# Set background cursor.
# (2270338, 'NV', '320310035043', 2001, '35.04.3', 'Washoe County, Nevada', 79.34, 1.68, 3.06, 41.76, 2170.74, 5321.61, 1.0, 92.13, 0.55, 4.67, 1.14, 0.59, 0.0, 0.93, 0.0, 6.0, 1.0, 1.0, 16.36, 16.36, False, False, '32', '32031', '32031003504', '320310035043', 2001, 0, 1)
#          _id state_code        geo_id  year     name          parent_location  \
# 995  2387223         NY  360810058004  2004     58.4  Queens County, New York
# 996  2387253         NY  360810059003  2004     59.3  Queens County, New York
# 997  2387330         NY  360810062022  2001  62.02.2  Queens County, New York
# 998  2387485         NY  360810065023  2006  65.02.3  Queens County, New York
# 999  2387491         NY  360810069001  2002     69.1  Queens County, New York
#
#      population  poverty_rate  pct_renter_occupied  median_gross_rent  \
# 995       957.0          5.22                23.89             909.00
# 996      1192.0         14.18                89.26             748.00
# 997       674.0          7.69                40.28             116.32
# 998      1887.0          0.00                81.45            1207.00
# 999      1367.0         25.60                80.50             796.00
#
#             ...           eviction_filing_rate  imputed  subbed  state  \
# 995         ...                           1.39    False   False     36
# 996         ...                           8.67    False   False     36
# 997         ...                           3.76    False   False     36
# 998         ...                           4.76    False   False     36
# 999         ...                           8.33    False   False     36
#
#      county        tract  geo_id (repeated)  year (repeated)  top20_evictions  \
# 995   36081  36081005800       360810058004             2004                0
# 996   36081  36081005900       360810059003             2004                1
# 997   36081  36081006202       360810062022             2001                0
# 998   36081  36081006502       360810065023             2006                1
# 999   36081  36081006900       360810069001             2002                0
#
#      top20_eviction_rate
# 995                    0
# 996                    0
# 997                    0
# 998                    0
# 999                    0
#
# [5 rows x 35 columns]

# %%
# define models to run
models_to_run=['RF','LR', 'NB', 'GB', 'DT', 'KNN'] #'SVM'
# select features to use
features  =  ['geo_id', 'population', 'evictions', 'eviction_filings', 'eviction_filing_rate', 'renter_occupied_households']

classifiers, params = pipeline.get_classifiers()
df = pipeline.fill_missing(df)

X = df[features]
y = df['top20_eviction_rate']

results_df = pipeline.classify(models_to_run, classifiers, params, X,y)


# save to csv
#results_df.to_csv('results.csv', index=False)
results_df
# Out:
# Running through model RF...
# Running through model LR...
# Running through model NB...
# Running through model GB...
# Running through model DT...
# Running through model KNN...
#     model_type                                                clf  \
# 0           RF  (DecisionTreeClassifier(class_weight=None, cri...
# 1           LR  LogisticRegression(C=10, class_weight=None, du...
# 2           LR  LogisticRegression(C=10, class_weight=None, du...
# 3           LR  LogisticRegression(C=10, class_weight=None, du...
# 4           LR  LogisticRegression(C=10, class_weight=None, du...
# 5           LR  LogisticRegression(C=10, class_weight=None, du...
# 6           LR  LogisticRegression(C=10, class_weight=None, du...
# 7           LR  LogisticRegression(C=10, class_weight=None, du...
# 8           LR  LogisticRegression(C=10, class_weight=None, du...
# 9           LR  LogisticRegression(C=10, class_weight=None, du...
# 10          LR  LogisticRegression(C=10, class_weight=None, du...
# 11          NB                            GaussianNB(priors=None)
# 12          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 13          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 14          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 15          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 16          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 17          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 18          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 19          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 20          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 21          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 22          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 23          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 24          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 25          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 26          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 27          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 28          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 29          GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# ..         ...                                                ...
# 90         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 91         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 92         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 93         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 94         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 95         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 96         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 97         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 98         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 99         KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 100        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 101        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 102        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 103        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 104        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 105        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 106        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 107        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 108        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 109        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 110        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 111        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 112        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 113        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 114        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 115        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 116        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 117        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 118        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 119        KNN  KNeighborsClassifier(algorithm='kd_tree', leaf...
#
#                                             parameters   auc-roc    p_at_5  \
# 0    {'max_depth': 1, 'max_features': 'sqrt', 'min_...  0.813222  0.333333
# 1                        {'C': 1e-05, 'penalty': 'l1'}  0.817598  0.583333
# 2                        {'C': 1e-05, 'penalty': 'l2'}  0.817598  0.583333
# 3                        {'C': 0.001, 'penalty': 'l1'}  0.963240  0.916667
# 4                        {'C': 0.001, 'penalty': 'l2'}  0.817598  0.583333
# 5                          {'C': 0.1, 'penalty': 'l1'}  0.995215  1.000000
# 6                          {'C': 0.1, 'penalty': 'l2'}  0.817598  0.583333
# 7                            {'C': 1, 'penalty': 'l1'}  0.995565  1.000000
# 8                            {'C': 1, 'penalty': 'l2'}  0.817598  0.583333
# 9                           {'C': 10, 'penalty': 'l1'}  0.995682  1.000000
# 10                          {'C': 10, 'penalty': 'l2'}  0.817598  0.583333
# 11                                                  {}  0.817482  0.666667
# 12   {'learning_rate': 0.001, 'max_depth': 5, 'n_es...  0.962889  1.000000
# 13   {'learning_rate': 0.001, 'max_depth': 5, 'n_es...  0.971467  1.000000
# 14   {'learning_rate': 0.001, 'max_depth': 5, 'n_es...  0.938558  0.750000
# 15   {'learning_rate': 0.001, 'max_depth': 5, 'n_es...  0.985763  1.000000
# 16   {'learning_rate': 0.001, 'max_depth': 5, 'n_es...  0.990547  1.000000
# 17   {'learning_rate': 0.001, 'max_depth': 5, 'n_es...  0.952153  0.916667
# 18   {'learning_rate': 0.001, 'max_depth': 50, 'n_e...  0.983545  1.000000
# 19   {'learning_rate': 0.001, 'max_depth': 50, 'n_e...  0.990431  1.000000
# 20   {'learning_rate': 0.001, 'max_depth': 50, 'n_e...  0.931206  1.000000
# 21   {'learning_rate': 0.001, 'max_depth': 50, 'n_e...  0.987046  1.000000
# 22   {'learning_rate': 0.001, 'max_depth': 50, 'n_e...  0.993348  1.000000
# 23   {'learning_rate': 0.001, 'max_depth': 50, 'n_e...  0.932197  0.916667
# 24   {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...  0.945968  1.000000
# 25   {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...  0.989964  1.000000
# 26   {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...  0.950811  0.916667
# 27   {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...  0.991481  1.000000
# 28   {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...  0.992181  1.000000
# 29   {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...  0.991714  1.000000
# ..                                                 ...       ...       ...
# 90   {'algorithm': 'auto', 'n_neighbors': 25, 'weig...  0.875190  0.666667
# 91   {'algorithm': 'auto', 'n_neighbors': 25, 'weig...  0.883767  0.583333
# 92   {'algorithm': 'auto', 'n_neighbors': 50, 'weig...  0.873906  0.583333
# 93   {'algorithm': 'auto', 'n_neighbors': 50, 'weig...  0.890652  0.500000
# 94   {'algorithm': 'auto', 'n_neighbors': 100, 'wei...  0.860544  0.250000
# 95   {'algorithm': 'auto', 'n_neighbors': 100, 'wei...  0.888202  0.500000
# 96   {'algorithm': 'ball_tree', 'n_neighbors': 1, '...  0.703233  0.166667
# 97   {'algorithm': 'ball_tree', 'n_neighbors': 1, '...  0.703233  0.166667
# 98   {'algorithm': 'ball_tree', 'n_neighbors': 5, '...  0.844323  0.500000
# 99   {'algorithm': 'ball_tree', 'n_neighbors': 5, '...  0.856284  0.500000
# 100  {'algorithm': 'ball_tree', 'n_neighbors': 10, ...  0.837904  0.666667
# 101  {'algorithm': 'ball_tree', 'n_neighbors': 10, ...  0.865037  0.500000
# 102  {'algorithm': 'ball_tree', 'n_neighbors': 25, ...  0.875190  0.666667
# 103  {'algorithm': 'ball_tree', 'n_neighbors': 25, ...  0.883767  0.583333
# 104  {'algorithm': 'ball_tree', 'n_neighbors': 50, ...  0.873906  0.583333
# 105  {'algorithm': 'ball_tree', 'n_neighbors': 50, ...  0.890652  0.500000
# 106  {'algorithm': 'ball_tree', 'n_neighbors': 100,...  0.860544  0.250000
# 107  {'algorithm': 'ball_tree', 'n_neighbors': 100,...  0.888202  0.500000
# 108  {'algorithm': 'kd_tree', 'n_neighbors': 1, 'we...  0.703233  0.166667
# 109  {'algorithm': 'kd_tree', 'n_neighbors': 1, 'we...  0.703233  0.166667
# 110  {'algorithm': 'kd_tree', 'n_neighbors': 5, 'we...  0.844323  0.500000
# 111  {'algorithm': 'kd_tree', 'n_neighbors': 5, 'we...  0.856284  0.500000
# 112  {'algorithm': 'kd_tree', 'n_neighbors': 10, 'w...  0.837904  0.666667
# 113  {'algorithm': 'kd_tree', 'n_neighbors': 10, 'w...  0.865037  0.500000
# 114  {'algorithm': 'kd_tree', 'n_neighbors': 25, 'w...  0.875190  0.666667
# 115  {'algorithm': 'kd_tree', 'n_neighbors': 25, 'w...  0.883767  0.583333
# 116  {'algorithm': 'kd_tree', 'n_neighbors': 50, 'w...  0.873906  0.583333
# 117  {'algorithm': 'kd_tree', 'n_neighbors': 50, 'w...  0.890652  0.500000
# 118  {'algorithm': 'kd_tree', 'n_neighbors': 100, '...  0.860544  0.250000
# 119  {'algorithm': 'kd_tree', 'n_neighbors': 100, '...  0.888202  0.500000
#
#      p_at_10  p_at_20
# 0       0.16     0.56
# 1       0.56     0.58
# 2       0.56     0.58
# 3       0.88     0.72
# 4       0.56     0.58
# 5       1.00     0.80
# 6       0.56     0.58
# 7       1.00     0.80
# 8       0.56     0.58
# 9       1.00     0.80
# 10      0.56     0.58
# 11      0.52     0.58
# 12      0.96     0.74
# 13      1.00     0.78
# 14      0.88     0.74
# 15      0.92     0.78
# 16      0.96     0.78
# 17      0.92     0.76
# 18      0.96     0.72
# 19      1.00     0.78
# 20      0.88     0.72
# 21      0.92     0.78
# 22      1.00     0.80
# 23      0.88     0.72
# 24      0.84     0.72
# 25      0.96     0.78
# 26      0.92     0.74
# 27      0.96     0.78
# 28      1.00     0.78
# 29      1.00     0.76
# ..       ...      ...
# 90      0.52     0.58
# 91      0.56     0.54
# 92      0.52     0.52
# 93      0.56     0.52
# 94      0.56     0.52
# 95      0.56     0.54
# 96      0.32     0.40
# 97      0.32     0.40
# 98      0.56     0.44
# 99      0.56     0.54
# 100     0.60     0.50
# 101     0.56     0.54
# 102     0.52     0.58
# 103     0.56     0.54
# 104     0.52     0.52
# 105     0.56     0.52
# 106     0.56     0.52
# 107     0.56     0.54
# 108     0.32     0.40
# 109     0.32     0.40
# 110     0.56     0.44
# 111     0.56     0.54
# 112     0.60     0.50
# 113     0.56     0.54
# 114     0.52     0.58
# 115     0.56     0.54
# 116     0.52     0.52
# 117     0.56     0.52
# 118     0.56     0.52
# 119     0.56     0.54
#
# [120 rows x 7 columns]
