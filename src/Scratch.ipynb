# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import warnings
import ml_utils as ml
import graphviz
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')

# %%
results, pipeline = ml.main()
# Out:
# Connected to evictions DB.
# Set schema to 'evictions'.
# Set background cursor.
# Loading chunk....
# 0 chunks left to load.
#
# Temporally validating on:
# Train: 2005-01-01 00:00:00 - 2005-12-31 00:00:00
# Test: 2006-01-01 00:00:00 - 2006-12-31 00:00:00
# Prediction window: 12 months
#
# []
# []
# []
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# []
# []
# []
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# []
# []
# []
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# []
# []
# []
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['eviction_filings_lag', 'evictions_lag', 'eviction_rate_lag', 'eviction_filing_rate_lag', 'conversion_rate_lag', 'eviction_filings_pct_change_1yr_lag', 'evictions_pct_change_1yr_lag', 'eviction_rate_pct_change_1yr_lag', 'eviction_filing_rate_pct_change_1yr_lag', 'conversion_rate_pct_change_1yr_lag', 'eviction_filings_pct_change_3yr_lag', 'evictions_pct_change_3yr_lag', 'eviction_rate_pct_change_3yr_lag', 'eviction_filing_rate_pct_change_3yr_lag', 'conversion_rate_pct_change_3yr_lag', 'eviction_filings_pct_change_5yr_lag', 'evictions_pct_change_5yr_lag', 'eviction_rate_pct_change_5yr_lag', 'eviction_filing_rate_pct_change_5yr_lag', 'conversion_rate_pct_change_5yr_lag']
# []
# ['eviction_filings_lag', 'evictions_lag', 'eviction_rate_lag', 'eviction_filing_rate_lag', 'conversion_rate_lag', 'eviction_filings_pct_change_1yr_lag', 'evictions_pct_change_1yr_lag', 'eviction_rate_pct_change_1yr_lag', 'eviction_filing_rate_pct_change_1yr_lag', 'conversion_rate_pct_change_1yr_lag', 'eviction_filings_pct_change_3yr_lag', 'evictions_pct_change_3yr_lag', 'eviction_rate_pct_change_3yr_lag', 'eviction_filing_rate_pct_change_3yr_lag', 'conversion_rate_pct_change_3yr_lag', 'eviction_filings_pct_change_5yr_lag', 'evictions_pct_change_5yr_lag', 'eviction_rate_pct_change_5yr_lag', 'eviction_filing_rate_pct_change_5yr_lag', 'conversion_rate_pct_change_5yr_lag']
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['eviction_filings_lag', 'evictions_lag', 'eviction_rate_lag', 'eviction_filing_rate_lag', 'conversion_rate_lag', 'eviction_filings_pct_change_1yr_lag', 'evictions_pct_change_1yr_lag', 'eviction_rate_pct_change_1yr_lag', 'eviction_filing_rate_pct_change_1yr_lag', 'conversion_rate_pct_change_1yr_lag', 'eviction_filings_pct_change_3yr_lag', 'evictions_pct_change_3yr_lag', 'eviction_rate_pct_change_3yr_lag', 'eviction_filing_rate_pct_change_3yr_lag', 'conversion_rate_pct_change_3yr_lag', 'eviction_filings_pct_change_5yr_lag', 'evictions_pct_change_5yr_lag', 'eviction_rate_pct_change_5yr_lag', 'eviction_filing_rate_pct_change_5yr_lag', 'conversion_rate_pct_change_5yr_lag']
# []
# ['eviction_filings_lag', 'evictions_lag', 'eviction_rate_lag', 'eviction_filing_rate_lag', 'conversion_rate_lag', 'eviction_filings_pct_change_1yr_lag', 'evictions_pct_change_1yr_lag', 'eviction_rate_pct_change_1yr_lag', 'eviction_filing_rate_pct_change_1yr_lag', 'conversion_rate_pct_change_1yr_lag', 'eviction_filings_pct_change_3yr_lag', 'evictions_pct_change_3yr_lag', 'eviction_rate_pct_change_3yr_lag', 'eviction_filing_rate_pct_change_3yr_lag', 'conversion_rate_pct_change_3yr_lag', 'eviction_filings_pct_change_5yr_lag', 'evictions_pct_change_5yr_lag', 'eviction_rate_pct_change_5yr_lag', 'eviction_filing_rate_pct_change_5yr_lag', 'conversion_rate_pct_change_5yr_lag']
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['median_gross_rent_pct_change_5yr_tr', 'median_household_income_pct_change_5yr_tr', 'median_property_value_pct_change_5yr_tr', 'rent_burden_pct_change_5yr_tr']
# []
# []
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['median_gross_rent_pct_change_5yr_tr', 'median_household_income_pct_change_5yr_tr', 'median_property_value_pct_change_5yr_tr', 'rent_burden_pct_change_5yr_tr']
# []
# []
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['eviction_filings_lag_tr', 'evictions_lag_tr', 'eviction_rate_lag_tr', 'eviction_filing_rate_lag_tr', 'conversion_rate_lag_tr', 'eviction_filings_pct_change_1yr_lag_tr', 'evictions_pct_change_1yr_lag_tr', 'eviction_rate_pct_change_1yr_lag_tr', 'eviction_filing_rate_pct_change_1yr_lag_tr', 'conversion_rate_pct_change_1yr_lag_tr', 'eviction_filings_pct_change_3yr_lag_tr', 'evictions_pct_change_3yr_lag_tr', 'eviction_rate_pct_change_3yr_lag_tr', 'eviction_filing_rate_pct_change_3yr_lag_tr', 'conversion_rate_pct_change_3yr_lag_tr', 'eviction_filings_pct_change_5yr_lag_tr', 'evictions_pct_change_5yr_lag_tr', 'eviction_rate_pct_change_5yr_lag_tr', 'eviction_filing_rate_pct_change_5yr_lag_tr', 'conversion_rate_pct_change_5yr_lag_tr']
# []
# ['eviction_filings_lag_tr', 'evictions_lag_tr', 'eviction_rate_lag_tr', 'eviction_filing_rate_lag_tr', 'conversion_rate_lag_tr', 'eviction_filings_pct_change_1yr_lag_tr', 'evictions_pct_change_1yr_lag_tr', 'eviction_rate_pct_change_1yr_lag_tr', 'eviction_filing_rate_pct_change_1yr_lag_tr', 'conversion_rate_pct_change_1yr_lag_tr', 'eviction_filings_pct_change_3yr_lag_tr', 'evictions_pct_change_3yr_lag_tr', 'eviction_rate_pct_change_3yr_lag_tr', 'eviction_filing_rate_pct_change_3yr_lag_tr', 'conversion_rate_pct_change_3yr_lag_tr', 'eviction_filings_pct_change_5yr_lag_tr', 'evictions_pct_change_5yr_lag_tr', 'eviction_rate_pct_change_5yr_lag_tr', 'eviction_filing_rate_pct_change_5yr_lag_tr', 'conversion_rate_pct_change_5yr_lag_tr']
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['eviction_filings_lag_tr', 'evictions_lag_tr', 'eviction_rate_lag_tr', 'eviction_filing_rate_lag_tr', 'conversion_rate_lag_tr', 'eviction_filings_pct_change_1yr_lag_tr', 'evictions_pct_change_1yr_lag_tr', 'eviction_rate_pct_change_1yr_lag_tr', 'eviction_filing_rate_pct_change_1yr_lag_tr', 'conversion_rate_pct_change_1yr_lag_tr', 'eviction_filings_pct_change_3yr_lag_tr', 'evictions_pct_change_3yr_lag_tr', 'eviction_rate_pct_change_3yr_lag_tr', 'eviction_filing_rate_pct_change_3yr_lag_tr', 'conversion_rate_pct_change_3yr_lag_tr', 'eviction_filings_pct_change_5yr_lag_tr', 'evictions_pct_change_5yr_lag_tr', 'eviction_rate_pct_change_5yr_lag_tr', 'eviction_filing_rate_pct_change_5yr_lag_tr', 'conversion_rate_pct_change_5yr_lag_tr']
# []
# ['eviction_filings_lag_tr', 'evictions_lag_tr', 'eviction_rate_lag_tr', 'eviction_filing_rate_lag_tr', 'conversion_rate_lag_tr', 'eviction_filings_pct_change_1yr_lag_tr', 'evictions_pct_change_1yr_lag_tr', 'eviction_rate_pct_change_1yr_lag_tr', 'eviction_filing_rate_pct_change_1yr_lag_tr', 'conversion_rate_pct_change_1yr_lag_tr', 'eviction_filings_pct_change_3yr_lag_tr', 'evictions_pct_change_3yr_lag_tr', 'eviction_rate_pct_change_3yr_lag_tr', 'eviction_filing_rate_pct_change_3yr_lag_tr', 'conversion_rate_pct_change_3yr_lag_tr', 'eviction_filings_pct_change_5yr_lag_tr', 'evictions_pct_change_5yr_lag_tr', 'eviction_rate_pct_change_5yr_lag_tr', 'eviction_filing_rate_pct_change_5yr_lag_tr', 'conversion_rate_pct_change_5yr_lag_tr']
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# []
# []
# []
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# []
# []
# []
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['eviction_filings_lag', 'evictions_lag', 'eviction_rate_lag', 'eviction_filing_rate_lag', 'conversion_rate_lag', 'eviction_filings_avg_3yr_lag', 'evictions_avg_3yr_lag', 'eviction_rate_avg_3yr_lag', 'eviction_filing_rate_avg_3yr_lag', 'eviction_filings_avg_5yr_lag', 'evictions_avg_5yr_lag', 'eviction_rate_avg_5yr_lag', 'eviction_filing_rate_avg_5yr_lag', 'conversion_rate_avg_5yr_lag', 'eviction_filings_pct_change_1yr_lag', 'evictions_pct_change_1yr_lag', 'eviction_rate_pct_change_1yr_lag', 'eviction_filing_rate_pct_change_1yr_lag', 'conversion_rate_pct_change_1yr_lag', 'eviction_filings_pct_change_3yr_lag', 'evictions_pct_change_3yr_lag', 'eviction_rate_pct_change_3yr_lag', 'eviction_filing_rate_pct_change_3yr_lag', 'conversion_rate_pct_change_3yr_lag', 'eviction_filings_pct_change_5yr_lag', 'evictions_pct_change_5yr_lag', 'eviction_rate_pct_change_5yr_lag', 'eviction_filing_rate_pct_change_5yr_lag', 'conversion_rate_pct_change_5yr_lag']
# []
# ['eviction_filings_lag', 'evictions_lag', 'eviction_rate_lag', 'eviction_filing_rate_lag', 'conversion_rate_lag', 'eviction_filings_pct_change_1yr_lag', 'evictions_pct_change_1yr_lag', 'eviction_rate_pct_change_1yr_lag', 'eviction_filing_rate_pct_change_1yr_lag', 'conversion_rate_pct_change_1yr_lag', 'eviction_filings_pct_change_3yr_lag', 'evictions_pct_change_3yr_lag', 'eviction_rate_pct_change_3yr_lag', 'eviction_filing_rate_pct_change_3yr_lag', 'conversion_rate_pct_change_3yr_lag', 'eviction_filings_pct_change_5yr_lag', 'evictions_pct_change_5yr_lag', 'eviction_rate_pct_change_5yr_lag', 'eviction_filing_rate_pct_change_5yr_lag', 'conversion_rate_pct_change_5yr_lag']
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['eviction_filings_lag', 'evictions_lag', 'eviction_rate_lag', 'eviction_filing_rate_lag', 'conversion_rate_lag', 'eviction_filings_avg_3yr_lag', 'evictions_avg_3yr_lag', 'eviction_rate_avg_3yr_lag', 'eviction_filing_rate_avg_3yr_lag', 'eviction_filings_avg_5yr_lag', 'evictions_avg_5yr_lag', 'eviction_rate_avg_5yr_lag', 'eviction_filing_rate_avg_5yr_lag', 'conversion_rate_avg_5yr_lag', 'eviction_filings_pct_change_1yr_lag', 'evictions_pct_change_1yr_lag', 'eviction_rate_pct_change_1yr_lag', 'eviction_filing_rate_pct_change_1yr_lag', 'conversion_rate_pct_change_1yr_lag', 'eviction_filings_pct_change_3yr_lag', 'evictions_pct_change_3yr_lag', 'eviction_rate_pct_change_3yr_lag', 'eviction_filing_rate_pct_change_3yr_lag', 'conversion_rate_pct_change_3yr_lag', 'eviction_filings_pct_change_5yr_lag', 'evictions_pct_change_5yr_lag', 'eviction_rate_pct_change_5yr_lag', 'eviction_filing_rate_pct_change_5yr_lag', 'conversion_rate_pct_change_5yr_lag']
# []
# ['eviction_filings_lag', 'evictions_lag', 'eviction_rate_lag', 'eviction_filing_rate_lag', 'conversion_rate_lag', 'eviction_filings_pct_change_1yr_lag', 'evictions_pct_change_1yr_lag', 'eviction_rate_pct_change_1yr_lag', 'eviction_filing_rate_pct_change_1yr_lag', 'conversion_rate_pct_change_1yr_lag', 'eviction_filings_pct_change_3yr_lag', 'evictions_pct_change_3yr_lag', 'eviction_rate_pct_change_3yr_lag', 'eviction_filing_rate_pct_change_3yr_lag', 'conversion_rate_pct_change_3yr_lag', 'eviction_filings_pct_change_5yr_lag', 'evictions_pct_change_5yr_lag', 'eviction_rate_pct_change_5yr_lag', 'eviction_filing_rate_pct_change_5yr_lag', 'conversion_rate_pct_change_5yr_lag']
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['median_gross_rent_avg_5yr_tr', 'median_household_income_avg_5yr_tr', 'median_property_value_avg_5yr_tr', 'rent_burden_avg_5yr_tr', 'median_gross_rent_pct_change_5yr_tr', 'median_household_income_pct_change_5yr_tr', 'median_property_value_pct_change_5yr_tr', 'rent_burden_pct_change_5yr_tr']
# []
# []
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['median_gross_rent_avg_5yr_tr', 'median_household_income_avg_5yr_tr', 'median_property_value_avg_5yr_tr', 'rent_burden_avg_5yr_tr', 'median_gross_rent_pct_change_5yr_tr', 'median_household_income_pct_change_5yr_tr', 'median_property_value_pct_change_5yr_tr', 'rent_burden_pct_change_5yr_tr']
# []
# []
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['eviction_filings_lag_tr', 'evictions_lag_tr', 'eviction_rate_lag_tr', 'eviction_filing_rate_lag_tr', 'conversion_rate_lag_tr', 'eviction_filings_avg_3yr_lag_tr', 'evictions_avg_3yr_lag_tr', 'eviction_rate_avg_3yr_lag_tr', 'eviction_filing_rate_avg_3yr_lag_tr', 'eviction_filings_avg_5yr_lag_tr', 'evictions_avg_5yr_lag_tr', 'eviction_rate_avg_5yr_lag_tr', 'eviction_filing_rate_avg_5yr_lag_tr', 'conversion_rate_avg_5yr_lag_tr', 'eviction_filings_pct_change_1yr_lag_tr', 'evictions_pct_change_1yr_lag_tr', 'eviction_rate_pct_change_1yr_lag_tr', 'eviction_filing_rate_pct_change_1yr_lag_tr', 'conversion_rate_pct_change_1yr_lag_tr', 'eviction_filings_pct_change_3yr_lag_tr', 'evictions_pct_change_3yr_lag_tr', 'eviction_rate_pct_change_3yr_lag_tr', 'eviction_filing_rate_pct_change_3yr_lag_tr', 'conversion_rate_pct_change_3yr_lag_tr', 'eviction_filings_pct_change_5yr_lag_tr', 'evictions_pct_change_5yr_lag_tr', 'eviction_rate_pct_change_5yr_lag_tr', 'eviction_filing_rate_pct_change_5yr_lag_tr', 'conversion_rate_pct_change_5yr_lag_tr']
# []
# ['eviction_filings_lag_tr', 'evictions_lag_tr', 'eviction_rate_lag_tr', 'eviction_filing_rate_lag_tr', 'conversion_rate_lag_tr', 'eviction_filings_pct_change_1yr_lag_tr', 'evictions_pct_change_1yr_lag_tr', 'eviction_rate_pct_change_1yr_lag_tr', 'eviction_filing_rate_pct_change_1yr_lag_tr', 'conversion_rate_pct_change_1yr_lag_tr', 'eviction_filings_pct_change_3yr_lag_tr', 'evictions_pct_change_3yr_lag_tr', 'eviction_rate_pct_change_3yr_lag_tr', 'eviction_filing_rate_pct_change_3yr_lag_tr', 'conversion_rate_pct_change_3yr_lag_tr', 'eviction_filings_pct_change_5yr_lag_tr', 'evictions_pct_change_5yr_lag_tr', 'eviction_rate_pct_change_5yr_lag_tr', 'eviction_filing_rate_pct_change_5yr_lag_tr', 'conversion_rate_pct_change_5yr_lag_tr']
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['eviction_filings_lag_tr', 'evictions_lag_tr', 'eviction_rate_lag_tr', 'eviction_filing_rate_lag_tr', 'conversion_rate_lag_tr', 'eviction_filings_avg_3yr_lag_tr', 'evictions_avg_3yr_lag_tr', 'eviction_rate_avg_3yr_lag_tr', 'eviction_filing_rate_avg_3yr_lag_tr', 'eviction_filings_avg_5yr_lag_tr', 'evictions_avg_5yr_lag_tr', 'eviction_rate_avg_5yr_lag_tr', 'eviction_filing_rate_avg_5yr_lag_tr', 'conversion_rate_avg_5yr_lag_tr', 'eviction_filings_pct_change_1yr_lag_tr', 'evictions_pct_change_1yr_lag_tr', 'eviction_rate_pct_change_1yr_lag_tr', 'eviction_filing_rate_pct_change_1yr_lag_tr', 'conversion_rate_pct_change_1yr_lag_tr', 'eviction_filings_pct_change_3yr_lag_tr', 'evictions_pct_change_3yr_lag_tr', 'eviction_rate_pct_change_3yr_lag_tr', 'eviction_filing_rate_pct_change_3yr_lag_tr', 'conversion_rate_pct_change_3yr_lag_tr', 'eviction_filings_pct_change_5yr_lag_tr', 'evictions_pct_change_5yr_lag_tr', 'eviction_rate_pct_change_5yr_lag_tr', 'eviction_filing_rate_pct_change_5yr_lag_tr', 'conversion_rate_pct_change_5yr_lag_tr']
# []
# ['eviction_filings_lag_tr', 'evictions_lag_tr', 'eviction_rate_lag_tr', 'eviction_filing_rate_lag_tr', 'conversion_rate_lag_tr', 'eviction_filings_pct_change_1yr_lag_tr', 'evictions_pct_change_1yr_lag_tr', 'eviction_rate_pct_change_1yr_lag_tr', 'eviction_filing_rate_pct_change_1yr_lag_tr', 'conversion_rate_pct_change_1yr_lag_tr', 'eviction_filings_pct_change_3yr_lag_tr', 'evictions_pct_change_3yr_lag_tr', 'eviction_rate_pct_change_3yr_lag_tr', 'eviction_filing_rate_pct_change_3yr_lag_tr', 'conversion_rate_pct_change_3yr_lag_tr', 'eviction_filings_pct_change_5yr_lag_tr', 'evictions_pct_change_5yr_lag_tr', 'eviction_rate_pct_change_5yr_lag_tr', 'eviction_filing_rate_pct_change_5yr_lag_tr', 'conversion_rate_pct_change_5yr_lag_tr']
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['eviction_filings_lag', 'evictions_lag', 'eviction_rate_lag', 'eviction_filing_rate_lag', 'conversion_rate_lag', 'eviction_filings_avg_3yr_lag', 'evictions_avg_3yr_lag', 'eviction_rate_avg_3yr_lag', 'eviction_filing_rate_avg_3yr_lag', 'eviction_filings_avg_5yr_lag', 'evictions_avg_5yr_lag', 'eviction_rate_avg_5yr_lag', 'eviction_filing_rate_avg_5yr_lag', 'conversion_rate_avg_5yr_lag', 'eviction_filings_pct_change_1yr_lag', 'evictions_pct_change_1yr_lag', 'eviction_rate_pct_change_1yr_lag', 'eviction_filing_rate_pct_change_1yr_lag', 'conversion_rate_pct_change_1yr_lag', 'eviction_filings_pct_change_3yr_lag', 'evictions_pct_change_3yr_lag', 'eviction_rate_pct_change_3yr_lag', 'eviction_filing_rate_pct_change_3yr_lag', 'conversion_rate_pct_change_3yr_lag', 'eviction_filings_pct_change_5yr_lag', 'evictions_pct_change_5yr_lag', 'eviction_rate_pct_change_5yr_lag', 'eviction_filing_rate_pct_change_5yr_lag', 'conversion_rate_pct_change_5yr_lag']
# []
# ['eviction_filings_lag', 'evictions_lag', 'eviction_rate_lag', 'eviction_filing_rate_lag', 'conversion_rate_lag', 'eviction_filings_pct_change_1yr_lag', 'evictions_pct_change_1yr_lag', 'eviction_rate_pct_change_1yr_lag', 'eviction_filing_rate_pct_change_1yr_lag', 'conversion_rate_pct_change_1yr_lag', 'eviction_filings_pct_change_3yr_lag', 'evictions_pct_change_3yr_lag', 'eviction_rate_pct_change_3yr_lag', 'eviction_filing_rate_pct_change_3yr_lag', 'conversion_rate_pct_change_3yr_lag', 'eviction_filings_pct_change_5yr_lag', 'evictions_pct_change_5yr_lag', 'eviction_rate_pct_change_5yr_lag', 'eviction_filing_rate_pct_change_5yr_lag', 'conversion_rate_pct_change_5yr_lag']
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['eviction_filings_lag', 'evictions_lag', 'eviction_rate_lag', 'eviction_filing_rate_lag', 'conversion_rate_lag', 'eviction_filings_avg_3yr_lag', 'evictions_avg_3yr_lag', 'eviction_rate_avg_3yr_lag', 'eviction_filing_rate_avg_3yr_lag', 'eviction_filings_avg_5yr_lag', 'evictions_avg_5yr_lag', 'eviction_rate_avg_5yr_lag', 'eviction_filing_rate_avg_5yr_lag', 'conversion_rate_avg_5yr_lag', 'eviction_filings_pct_change_1yr_lag', 'evictions_pct_change_1yr_lag', 'eviction_rate_pct_change_1yr_lag', 'eviction_filing_rate_pct_change_1yr_lag', 'conversion_rate_pct_change_1yr_lag', 'eviction_filings_pct_change_3yr_lag', 'evictions_pct_change_3yr_lag', 'eviction_rate_pct_change_3yr_lag', 'eviction_filing_rate_pct_change_3yr_lag', 'conversion_rate_pct_change_3yr_lag', 'eviction_filings_pct_change_5yr_lag', 'evictions_pct_change_5yr_lag', 'eviction_rate_pct_change_5yr_lag', 'eviction_filing_rate_pct_change_5yr_lag', 'conversion_rate_pct_change_5yr_lag']
# []
# ['eviction_filings_lag', 'evictions_lag', 'eviction_rate_lag', 'eviction_filing_rate_lag', 'conversion_rate_lag', 'eviction_filings_pct_change_1yr_lag', 'evictions_pct_change_1yr_lag', 'eviction_rate_pct_change_1yr_lag', 'eviction_filing_rate_pct_change_1yr_lag', 'conversion_rate_pct_change_1yr_lag', 'eviction_filings_pct_change_3yr_lag', 'evictions_pct_change_3yr_lag', 'eviction_rate_pct_change_3yr_lag', 'eviction_filing_rate_pct_change_3yr_lag', 'conversion_rate_pct_change_3yr_lag', 'eviction_filings_pct_change_5yr_lag', 'evictions_pct_change_5yr_lag', 'eviction_rate_pct_change_5yr_lag', 'eviction_filing_rate_pct_change_5yr_lag', 'conversion_rate_pct_change_5yr_lag']
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['median_gross_rent_avg_5yr_tr', 'median_household_income_avg_5yr_tr', 'median_property_value_avg_5yr_tr', 'rent_burden_avg_5yr_tr', 'median_gross_rent_pct_change_5yr_tr', 'median_household_income_pct_change_5yr_tr', 'median_property_value_pct_change_5yr_tr', 'rent_burden_pct_change_5yr_tr']
# []
# []
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['median_gross_rent_avg_5yr_tr', 'median_household_income_avg_5yr_tr', 'median_property_value_avg_5yr_tr', 'rent_burden_avg_5yr_tr', 'median_gross_rent_pct_change_5yr_tr', 'median_household_income_pct_change_5yr_tr', 'median_property_value_pct_change_5yr_tr', 'rent_burden_pct_change_5yr_tr']
# []
# []
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['eviction_filings_lag_tr', 'evictions_lag_tr', 'eviction_rate_lag_tr', 'eviction_filing_rate_lag_tr', 'conversion_rate_lag_tr', 'eviction_filings_avg_3yr_lag_tr', 'evictions_avg_3yr_lag_tr', 'eviction_rate_avg_3yr_lag_tr', 'eviction_filing_rate_avg_3yr_lag_tr', 'eviction_filings_avg_5yr_lag_tr', 'evictions_avg_5yr_lag_tr', 'eviction_rate_avg_5yr_lag_tr', 'eviction_filing_rate_avg_5yr_lag_tr', 'conversion_rate_avg_5yr_lag_tr', 'eviction_filings_pct_change_1yr_lag_tr', 'evictions_pct_change_1yr_lag_tr', 'eviction_rate_pct_change_1yr_lag_tr', 'eviction_filing_rate_pct_change_1yr_lag_tr', 'conversion_rate_pct_change_1yr_lag_tr', 'eviction_filings_pct_change_3yr_lag_tr', 'evictions_pct_change_3yr_lag_tr', 'eviction_rate_pct_change_3yr_lag_tr', 'eviction_filing_rate_pct_change_3yr_lag_tr', 'conversion_rate_pct_change_3yr_lag_tr', 'eviction_filings_pct_change_5yr_lag_tr', 'evictions_pct_change_5yr_lag_tr', 'eviction_rate_pct_change_5yr_lag_tr', 'eviction_filing_rate_pct_change_5yr_lag_tr', 'conversion_rate_pct_change_5yr_lag_tr']
# []
# ['eviction_filings_lag_tr', 'evictions_lag_tr', 'eviction_rate_lag_tr', 'eviction_filing_rate_lag_tr', 'conversion_rate_lag_tr', 'eviction_filings_pct_change_1yr_lag_tr', 'evictions_pct_change_1yr_lag_tr', 'eviction_rate_pct_change_1yr_lag_tr', 'eviction_filing_rate_pct_change_1yr_lag_tr', 'conversion_rate_pct_change_1yr_lag_tr', 'eviction_filings_pct_change_3yr_lag_tr', 'evictions_pct_change_3yr_lag_tr', 'eviction_rate_pct_change_3yr_lag_tr', 'eviction_filing_rate_pct_change_3yr_lag_tr', 'conversion_rate_pct_change_3yr_lag_tr', 'eviction_filings_pct_change_5yr_lag_tr', 'evictions_pct_change_5yr_lag_tr', 'eviction_rate_pct_change_5yr_lag_tr', 'eviction_filing_rate_pct_change_5yr_lag_tr', 'conversion_rate_pct_change_5yr_lag_tr']
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['eviction_filings_lag_tr', 'evictions_lag_tr', 'eviction_rate_lag_tr', 'eviction_filing_rate_lag_tr', 'conversion_rate_lag_tr', 'eviction_filings_avg_3yr_lag_tr', 'evictions_avg_3yr_lag_tr', 'eviction_rate_avg_3yr_lag_tr', 'eviction_filing_rate_avg_3yr_lag_tr', 'eviction_filings_avg_5yr_lag_tr', 'evictions_avg_5yr_lag_tr', 'eviction_rate_avg_5yr_lag_tr', 'eviction_filing_rate_avg_5yr_lag_tr', 'conversion_rate_avg_5yr_lag_tr', 'eviction_filings_pct_change_1yr_lag_tr', 'evictions_pct_change_1yr_lag_tr', 'eviction_rate_pct_change_1yr_lag_tr', 'eviction_filing_rate_pct_change_1yr_lag_tr', 'conversion_rate_pct_change_1yr_lag_tr', 'eviction_filings_pct_change_3yr_lag_tr', 'evictions_pct_change_3yr_lag_tr', 'eviction_rate_pct_change_3yr_lag_tr', 'eviction_filing_rate_pct_change_3yr_lag_tr', 'conversion_rate_pct_change_3yr_lag_tr', 'eviction_filings_pct_change_5yr_lag_tr', 'evictions_pct_change_5yr_lag_tr', 'eviction_rate_pct_change_5yr_lag_tr', 'eviction_filing_rate_pct_change_5yr_lag_tr', 'conversion_rate_pct_change_5yr_lag_tr']
# []
# ['eviction_filings_lag_tr', 'evictions_lag_tr', 'eviction_rate_lag_tr', 'eviction_filing_rate_lag_tr', 'conversion_rate_lag_tr', 'eviction_filings_pct_change_1yr_lag_tr', 'evictions_pct_change_1yr_lag_tr', 'eviction_rate_pct_change_1yr_lag_tr', 'eviction_filing_rate_pct_change_1yr_lag_tr', 'conversion_rate_pct_change_1yr_lag_tr', 'eviction_filings_pct_change_3yr_lag_tr', 'evictions_pct_change_3yr_lag_tr', 'eviction_rate_pct_change_3yr_lag_tr', 'eviction_filing_rate_pct_change_3yr_lag_tr', 'conversion_rate_pct_change_3yr_lag_tr', 'eviction_filings_pct_change_5yr_lag_tr', 'evictions_pct_change_5yr_lag_tr', 'eviction_rate_pct_change_5yr_lag_tr', 'eviction_filing_rate_pct_change_5yr_lag_tr', 'conversion_rate_pct_change_5yr_lag_tr']
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['eviction_filings_lag', 'evictions_lag', 'eviction_rate_lag', 'eviction_filing_rate_lag', 'conversion_rate_lag', 'eviction_filings_avg_3yr_lag', 'evictions_avg_3yr_lag', 'eviction_rate_avg_3yr_lag', 'eviction_filing_rate_avg_3yr_lag', 'eviction_filings_avg_5yr_lag', 'evictions_avg_5yr_lag', 'eviction_rate_avg_5yr_lag', 'eviction_filing_rate_avg_5yr_lag', 'conversion_rate_avg_5yr_lag', 'eviction_filings_pct_change_1yr_lag', 'evictions_pct_change_1yr_lag', 'eviction_rate_pct_change_1yr_lag', 'eviction_filing_rate_pct_change_1yr_lag', 'conversion_rate_pct_change_1yr_lag', 'eviction_filings_pct_change_3yr_lag', 'evictions_pct_change_3yr_lag', 'eviction_rate_pct_change_3yr_lag', 'eviction_filing_rate_pct_change_3yr_lag', 'conversion_rate_pct_change_3yr_lag', 'eviction_filings_pct_change_5yr_lag', 'evictions_pct_change_5yr_lag', 'eviction_rate_pct_change_5yr_lag', 'eviction_filing_rate_pct_change_5yr_lag', 'conversion_rate_pct_change_5yr_lag', 'median_gross_rent_avg_5yr_tr', 'median_household_income_avg_5yr_tr', 'median_property_value_avg_5yr_tr', 'rent_burden_avg_5yr_tr', 'median_gross_rent_pct_change_5yr_tr', 'median_household_income_pct_change_5yr_tr', 'median_property_value_pct_change_5yr_tr', 'rent_burden_pct_change_5yr_tr']
# []
# ['eviction_filings_lag', 'evictions_lag', 'eviction_rate_lag', 'eviction_filing_rate_lag', 'conversion_rate_lag', 'eviction_filings_pct_change_1yr_lag', 'evictions_pct_change_1yr_lag', 'eviction_rate_pct_change_1yr_lag', 'eviction_filing_rate_pct_change_1yr_lag', 'conversion_rate_pct_change_1yr_lag', 'eviction_filings_pct_change_3yr_lag', 'evictions_pct_change_3yr_lag', 'eviction_rate_pct_change_3yr_lag', 'eviction_filing_rate_pct_change_3yr_lag', 'conversion_rate_pct_change_3yr_lag', 'eviction_filings_pct_change_5yr_lag', 'evictions_pct_change_5yr_lag', 'eviction_rate_pct_change_5yr_lag', 'eviction_filing_rate_pct_change_5yr_lag', 'conversion_rate_pct_change_5yr_lag']
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['eviction_filings_lag', 'evictions_lag', 'eviction_rate_lag', 'eviction_filing_rate_lag', 'conversion_rate_lag', 'eviction_filings_avg_3yr_lag', 'evictions_avg_3yr_lag', 'eviction_rate_avg_3yr_lag', 'eviction_filing_rate_avg_3yr_lag', 'eviction_filings_avg_5yr_lag', 'evictions_avg_5yr_lag', 'eviction_rate_avg_5yr_lag', 'eviction_filing_rate_avg_5yr_lag', 'conversion_rate_avg_5yr_lag', 'eviction_filings_pct_change_1yr_lag', 'evictions_pct_change_1yr_lag', 'eviction_rate_pct_change_1yr_lag', 'eviction_filing_rate_pct_change_1yr_lag', 'conversion_rate_pct_change_1yr_lag', 'eviction_filings_pct_change_3yr_lag', 'evictions_pct_change_3yr_lag', 'eviction_rate_pct_change_3yr_lag', 'eviction_filing_rate_pct_change_3yr_lag', 'conversion_rate_pct_change_3yr_lag', 'eviction_filings_pct_change_5yr_lag', 'evictions_pct_change_5yr_lag', 'eviction_rate_pct_change_5yr_lag', 'eviction_filing_rate_pct_change_5yr_lag', 'conversion_rate_pct_change_5yr_lag', 'median_gross_rent_avg_5yr_tr', 'median_household_income_avg_5yr_tr', 'median_property_value_avg_5yr_tr', 'rent_burden_avg_5yr_tr', 'median_gross_rent_pct_change_5yr_tr', 'median_household_income_pct_change_5yr_tr', 'median_property_value_pct_change_5yr_tr', 'rent_burden_pct_change_5yr_tr']
# []
# ['eviction_filings_lag', 'evictions_lag', 'eviction_rate_lag', 'eviction_filing_rate_lag', 'conversion_rate_lag', 'eviction_filings_pct_change_1yr_lag', 'evictions_pct_change_1yr_lag', 'eviction_rate_pct_change_1yr_lag', 'eviction_filing_rate_pct_change_1yr_lag', 'conversion_rate_pct_change_1yr_lag', 'eviction_filings_pct_change_3yr_lag', 'evictions_pct_change_3yr_lag', 'eviction_rate_pct_change_3yr_lag', 'eviction_filing_rate_pct_change_3yr_lag', 'conversion_rate_pct_change_3yr_lag', 'eviction_filings_pct_change_5yr_lag', 'evictions_pct_change_5yr_lag', 'eviction_rate_pct_change_5yr_lag', 'eviction_filing_rate_pct_change_5yr_lag', 'conversion_rate_pct_change_5yr_lag']
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['eviction_filings_lag', 'evictions_lag', 'eviction_rate_lag', 'eviction_filing_rate_lag', 'conversion_rate_lag', 'eviction_filings_avg_3yr_lag', 'evictions_avg_3yr_lag', 'eviction_rate_avg_3yr_lag', 'eviction_filing_rate_avg_3yr_lag', 'eviction_filings_avg_5yr_lag', 'evictions_avg_5yr_lag', 'eviction_rate_avg_5yr_lag', 'eviction_filing_rate_avg_5yr_lag', 'conversion_rate_avg_5yr_lag', 'eviction_filings_pct_change_1yr_lag', 'evictions_pct_change_1yr_lag', 'eviction_rate_pct_change_1yr_lag', 'eviction_filing_rate_pct_change_1yr_lag', 'conversion_rate_pct_change_1yr_lag', 'eviction_filings_pct_change_3yr_lag', 'evictions_pct_change_3yr_lag', 'eviction_rate_pct_change_3yr_lag', 'eviction_filing_rate_pct_change_3yr_lag', 'conversion_rate_pct_change_3yr_lag', 'eviction_filings_pct_change_5yr_lag', 'evictions_pct_change_5yr_lag', 'eviction_rate_pct_change_5yr_lag', 'eviction_filing_rate_pct_change_5yr_lag', 'conversion_rate_pct_change_5yr_lag', 'eviction_filings_lag_tr', 'evictions_lag_tr', 'eviction_rate_lag_tr', 'eviction_filing_rate_lag_tr', 'conversion_rate_lag_tr', 'eviction_filings_avg_3yr_lag_tr', 'evictions_avg_3yr_lag_tr', 'eviction_rate_avg_3yr_lag_tr', 'eviction_filing_rate_avg_3yr_lag_tr', 'eviction_filings_avg_5yr_lag_tr', 'evictions_avg_5yr_lag_tr', 'eviction_rate_avg_5yr_lag_tr', 'eviction_filing_rate_avg_5yr_lag_tr', 'conversion_rate_avg_5yr_lag_tr', 'eviction_filings_pct_change_1yr_lag_tr', 'evictions_pct_change_1yr_lag_tr', 'eviction_rate_pct_change_1yr_lag_tr', 'eviction_filing_rate_pct_change_1yr_lag_tr', 'conversion_rate_pct_change_1yr_lag_tr', 'eviction_filings_pct_change_3yr_lag_tr', 'evictions_pct_change_3yr_lag_tr', 'eviction_rate_pct_change_3yr_lag_tr', 'eviction_filing_rate_pct_change_3yr_lag_tr', 'conversion_rate_pct_change_3yr_lag_tr', 'eviction_filings_pct_change_5yr_lag_tr', 'evictions_pct_change_5yr_lag_tr', 'eviction_rate_pct_change_5yr_lag_tr', 'eviction_filing_rate_pct_change_5yr_lag_tr', 'conversion_rate_pct_change_5yr_lag_tr']
# []
# ['eviction_filings_lag', 'evictions_lag', 'eviction_rate_lag', 'eviction_filing_rate_lag', 'conversion_rate_lag', 'eviction_filings_pct_change_1yr_lag', 'evictions_pct_change_1yr_lag', 'eviction_rate_pct_change_1yr_lag', 'eviction_filing_rate_pct_change_1yr_lag', 'conversion_rate_pct_change_1yr_lag', 'eviction_filings_pct_change_3yr_lag', 'evictions_pct_change_3yr_lag', 'eviction_rate_pct_change_3yr_lag', 'eviction_filing_rate_pct_change_3yr_lag', 'conversion_rate_pct_change_3yr_lag', 'eviction_filings_pct_change_5yr_lag', 'evictions_pct_change_5yr_lag', 'eviction_rate_pct_change_5yr_lag', 'eviction_filing_rate_pct_change_5yr_lag', 'conversion_rate_pct_change_5yr_lag', 'eviction_filings_lag_tr', 'evictions_lag_tr', 'eviction_rate_lag_tr', 'eviction_filing_rate_lag_tr', 'conversion_rate_lag_tr', 'eviction_filings_pct_change_1yr_lag_tr', 'evictions_pct_change_1yr_lag_tr', 'eviction_rate_pct_change_1yr_lag_tr', 'eviction_filing_rate_pct_change_1yr_lag_tr', 'conversion_rate_pct_change_1yr_lag_tr', 'eviction_filings_pct_change_3yr_lag_tr', 'evictions_pct_change_3yr_lag_tr', 'eviction_rate_pct_change_3yr_lag_tr', 'eviction_filing_rate_pct_change_3yr_lag_tr', 'conversion_rate_pct_change_3yr_lag_tr', 'eviction_filings_pct_change_5yr_lag_tr', 'evictions_pct_change_5yr_lag_tr', 'eviction_rate_pct_change_5yr_lag_tr', 'eviction_filing_rate_pct_change_5yr_lag_tr', 'conversion_rate_pct_change_5yr_lag_tr']
# []
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 3, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# Running with params {'algorithm': 'kd_tree', 'n_neighbors': 10, 'weights': 'distance'}
# KNN finished.
# Running NB...
# Running with params {}
# NB finished.
# Running BASELINE_DT...
# Running with params {'criterion': 'gini', 'max_depth': 3}
# BASELINE_DT finished.
# ['eviction_filings_lag', 'evictions_lag', 'eviction_rate_lag', 'eviction_filing_rate_lag', 'conversion_rate_lag', 'eviction_filings_avg_3yr_lag', 'evictions_avg_3yr_lag', 'eviction_rate_avg_3yr_lag', 'eviction_filing_rate_avg_3yr_lag', 'eviction_filings_avg_5yr_lag', 'evictions_avg_5yr_lag', 'eviction_rate_avg_5yr_lag', 'eviction_filing_rate_avg_5yr_lag', 'conversion_rate_avg_5yr_lag', 'eviction_filings_pct_change_1yr_lag', 'evictions_pct_change_1yr_lag', 'eviction_rate_pct_change_1yr_lag', 'eviction_filing_rate_pct_change_1yr_lag', 'conversion_rate_pct_change_1yr_lag', 'eviction_filings_pct_change_3yr_lag', 'evictions_pct_change_3yr_lag', 'eviction_rate_pct_change_3yr_lag', 'eviction_filing_rate_pct_change_3yr_lag', 'conversion_rate_pct_change_3yr_lag', 'eviction_filings_pct_change_5yr_lag', 'evictions_pct_change_5yr_lag', 'eviction_rate_pct_change_5yr_lag', 'eviction_filing_rate_pct_change_5yr_lag', 'conversion_rate_pct_change_5yr_lag', 'eviction_filings_lag_tr', 'evictions_lag_tr', 'eviction_rate_lag_tr', 'eviction_filing_rate_lag_tr', 'conversion_rate_lag_tr', 'eviction_filings_avg_3yr_lag_tr', 'evictions_avg_3yr_lag_tr', 'eviction_rate_avg_3yr_lag_tr', 'eviction_filing_rate_avg_3yr_lag_tr', 'eviction_filings_avg_5yr_lag_tr', 'evictions_avg_5yr_lag_tr', 'eviction_rate_avg_5yr_lag_tr', 'eviction_filing_rate_avg_5yr_lag_tr', 'conversion_rate_avg_5yr_lag_tr', 'eviction_filings_pct_change_1yr_lag_tr', 'evictions_pct_change_1yr_lag_tr', 'eviction_rate_pct_change_1yr_lag_tr', 'eviction_filing_rate_pct_change_1yr_lag_tr', 'conversion_rate_pct_change_1yr_lag_tr', 'eviction_filings_pct_change_3yr_lag_tr', 'evictions_pct_change_3yr_lag_tr', 'eviction_rate_pct_change_3yr_lag_tr', 'eviction_filing_rate_pct_change_3yr_lag_tr', 'conversion_rate_pct_change_3yr_lag_tr', 'eviction_filings_pct_change_5yr_lag_tr', 'evictions_pct_change_5yr_lag_tr', 'eviction_rate_pct_change_5yr_lag_tr', 'eviction_filing_rate_pct_change_5yr_lag_tr', 'conversion_rate_pct_change_5yr_lag_tr']

# %%
results

# %%
results.iloc[1]['model_result'].tree_viz

# %% [markdown]
# !['hello'](test.svg)

# %%
sns.boxplot(x='model_key', y='auc-roc', data=results)
plt.xticks(rotation=70)

# %%
sns.boxplot(x='training_dates', y='auc-roc', data=results)
plt.xticks(rotation=90)

# %%
results['training_dates'].unique()

# %%
sns.factorplot(x='training_dates', y='auc-roc', data=results, col='model_key', col_wrap=1, kind='box', size=2, aspect=3)
