# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import warnings
import ml_utils as ml
import graphviz
import pandas as pd

warnings.filterwarnings('ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
results, pipeline = ml.main()
# Out:
# Connected to evictions DB.
# Set schema to 'evictions'.
# Set background cursor.
# Loading chunk....
# 0 chunks left to load.
#
# Temporally validating on:
# Train: 2006-01-01 00:00:00 - 2006-12-31 00:00:00
# Test: 2007-01-01 00:00:00 - 2007-12-31 00:00:00
# Prediction window: 12 months
#
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# [0.02833346 0.07951312 0.04780857 0.02641434 0.04771618 0.05092159
#  0.02657157 0.04739222 0.04307576 0.01324762 0.00457169 0.03950617
#  0.         0.03613279 0.00303914 0.07782034 0.03319574 0.04653929
#  0.03076134 0.06787967 0.03771188 0.03937823 0.04635046 0.01122208
#  0.04059413 0.00285832 0.023201   0.00409561 0.02096672 0.023181  ]
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# ...

# %%
results
# Out:
#                                 training_dates  \
# 0   (2006-01-01 00:00:00, 2006-12-31 00:00:00)
# 1   (2006-01-01 00:00:00, 2006-12-31 00:00:00)
# 2   (2006-01-01 00:00:00, 2006-12-31 00:00:00)
# 3   (2006-01-01 00:00:00, 2006-12-31 00:00:00)
# 4   (2006-01-01 00:00:00, 2006-12-31 00:00:00)
# 5   (2006-01-01 00:00:00, 2006-12-31 00:00:00)
# 6   (2006-01-01 00:00:00, 2006-12-31 00:00:00)
# 7   (2006-01-01 00:00:00, 2007-12-31 00:00:00)
# 8   (2006-01-01 00:00:00, 2007-12-31 00:00:00)
# 9   (2006-01-01 00:00:00, 2007-12-31 00:00:00)
# 10  (2006-01-01 00:00:00, 2007-12-31 00:00:00)
# 11  (2006-01-01 00:00:00, 2007-12-31 00:00:00)
# 12  (2006-01-01 00:00:00, 2007-12-31 00:00:00)
# 13  (2006-01-01 00:00:00, 2007-12-31 00:00:00)
# 14  (2006-01-01 00:00:00, 2008-12-31 00:00:00)
# 15  (2006-01-01 00:00:00, 2008-12-31 00:00:00)
# 16  (2006-01-01 00:00:00, 2008-12-31 00:00:00)
# 17  (2006-01-01 00:00:00, 2008-12-31 00:00:00)
# 18  (2006-01-01 00:00:00, 2008-12-31 00:00:00)
# ...

# %%
results['model_result'][58].coef
# Out:
#             coef                                    feature
# 0   6.328005e-06                                 population
# 1   6.437263e-04                               poverty_rate
# 2  -1.392414e-04                        pct_renter_occupied
# 3  -1.464072e-04                          median_gross_rent
# 4   9.569377e-07                    median_household_income
# 5  -5.924764e-06                      median_property_value
# 6   3.171403e-04                                rent_burden
# 7  -3.002864e-03                                  pct_white
# 8   1.819906e-03                                  pct_af_am
# 9  -3.079782e-04                               pct_hispanic
# 10 -4.078015e-05                                 pct_am_ind
# 11 -6.276632e-05                                  pct_asian
# 12  1.215866e-06                                  pct_nh_pi
# 13  9.972725e-05                               pct_multiple
# 14  2.739786e-06                                  pct_other
# ...

# %%
outcomes = results[results['model_key'] == 'RF']

for index, outcome in outcomes.iterrows():
    labels = []
    for fset in outcome['feature_sets']:
        labels.extend(pipeline.feature_dict[fset])

    fi = outcome['model_result'].feature_importances
    cols = labels
    
    fi_names = pd.DataFrame({'feature_import': fi, 'cols': cols})
    fi_names.sort_values(by=['feature_import'])
    print(fi_names)
    break
