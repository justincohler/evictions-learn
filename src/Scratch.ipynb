# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import warnings
import ml_utils as ml
import graphviz

warnings.filterwarnings('ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
results = ml.main()
# Out:
# Connected to evictions DB.
# Set schema to 'evictions'.
# Set background cursor.
# Loading chunk....
# 0 chunks left to load.
#
# Temporally validating on:
# Train: 2006-01-01 00:00:00 - 2006-12-31 00:00:00
# Test: 2007-01-01 00:00:00 - 2007-12-31 00:00:00
# Prediction window: 12 months
#
# Running RF...
# Running with params {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 10}
# RF finished.
# Running DT...
# Running with params {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10}
# DT finished.
# Running LR...
# Running with params {'C': 0.01, 'penalty': 'l2'}
# LR finished.
# Running BAG...
# Running with params {'bootstrap_features': True, 'max_features': 5, 'max_samples': 5, 'n_estimators': 5}
# BAG finished.
# Running GB...
# Running with params {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 5, 'subsample': 0.5}
# GB finished.
# Running KNN...
# ...

# %%
results
# Out:
#                                 training_dates  \
# 0   (2006-01-01 00:00:00, 2006-12-31 00:00:00)
# 1   (2006-01-01 00:00:00, 2006-12-31 00:00:00)
# 2   (2006-01-01 00:00:00, 2006-12-31 00:00:00)
# 3   (2006-01-01 00:00:00, 2006-12-31 00:00:00)
# 4   (2006-01-01 00:00:00, 2006-12-31 00:00:00)
# 5   (2006-01-01 00:00:00, 2006-12-31 00:00:00)
# 6   (2006-01-01 00:00:00, 2006-12-31 00:00:00)
# 7   (2006-01-01 00:00:00, 2007-12-31 00:00:00)
# 8   (2006-01-01 00:00:00, 2007-12-31 00:00:00)
# 9   (2006-01-01 00:00:00, 2007-12-31 00:00:00)
# 10  (2006-01-01 00:00:00, 2007-12-31 00:00:00)
# 11  (2006-01-01 00:00:00, 2007-12-31 00:00:00)
# 12  (2006-01-01 00:00:00, 2007-12-31 00:00:00)
# 13  (2006-01-01 00:00:00, 2007-12-31 00:00:00)
# 14  (2006-01-01 00:00:00, 2008-12-31 00:00:00)
# 15  (2006-01-01 00:00:00, 2008-12-31 00:00:00)
# 16  (2006-01-01 00:00:00, 2008-12-31 00:00:00)
# 17  (2006-01-01 00:00:00, 2008-12-31 00:00:00)
# 18  (2006-01-01 00:00:00, 2008-12-31 00:00:00)
# ...

# %%
results['model_result'][0].feature_importances
# Out:
# array([0.02888508, 0.10070082, 0.05532797, 0.00224751, 0.0089924 ,
#        0.05062746, 0.02277175, 0.06564599, 0.0970899 , 0.00359307,
#        0.0170754 , 0.01292129, 0.        , 0.08503784, 0.        ,
#        0.04342129, 0.01584345, 0.02095567, 0.01896296, 0.08507671,
#        0.0864797 , 0.01252853, 0.05778148, 0.02227165, 0.0252411 ,
#        0.00815092, 0.02083043, 0.        , 0.03153964, 0.        ])
